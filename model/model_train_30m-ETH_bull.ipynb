# %% [markdown]
# # RFCrypto

# %%
import matplotlib.pyplot as plt
import pandas as pd

COIN = 'ETHBUSD'
TIME = '30m'

# %%
# !python data_loader.py --coin ETHBUSD --time 15m

# %% [markdown]
# ## Klines

# %%
klines = pd.read_csv(f'./klines/{COIN}_{TIME}.csv')
klines = klines.iloc[:,1:]
klines['timestamp'] = pd.to_datetime(klines.timestamp)
klines
# Out:
#                 timestamp     open     high      low    close      volume  \
# 0     2021-03-01 00:00:00  1421.35  1450.88  1412.30  1441.50  9975.10635
# 1     2021-03-01 00:30:00  1441.73  1452.56  1441.19  1443.22  6350.20225
# 2     2021-03-01 01:00:00  1443.39  1449.55  1428.57  1435.20  6571.05176
# 3     2021-03-01 01:30:00  1435.04  1445.44  1434.62  1442.00  6196.16782
# 4     2021-03-01 02:00:00  1442.00  1458.62  1439.03  1452.11  8289.00965
# ...                   ...      ...      ...      ...      ...         ...
# 19358 2022-04-08 21:30:00  3237.45  3237.57  3214.37  3222.17  1487.87310
# 19359 2022-04-08 22:00:00  3222.65  3228.94  3192.33  3192.33  4534.63730
# 19360 2022-04-08 22:30:00  3192.31  3209.75  3186.55  3191.10  1826.88800
# 19361 2022-04-08 23:00:00  3191.10  3198.91  3175.88  3178.50  2805.18970
# 19362 2022-04-08 23:30:00  3178.51  3195.93  3171.94  3192.58  1392.22050
#
#            closetime  quoteassetvolume  numberoftrades  \
# 0      1614558599999      1.430813e+07           16898
# 1      1614560399999      9.185153e+06           12528
# 2      1614562199999      9.442462e+06           10972
# 3      1614563999999      8.922005e+06            9369
# 4      1614565799999      1.199415e+07           13042
# ...              ...               ...             ...
# 19358  1649455199999      4.795426e+06            5793
# 19359  1649456999999      1.453230e+07           11366
# 19360  1649458799999      5.844115e+06            5710
# 19361  1649460599999      8.936618e+06            9418
# 19362  1649462399999      4.432669e+06            5074
#
#        takerbuybaseassetvolume        time
# 0                   5022.33978  2021-03-01
# 1                   3154.76630  2021-03-01
# 2                   3084.98996  2021-03-01
# 3                   3188.12220  2021-03-01
# 4                   3857.25552  2021-03-01
# ...                        ...         ...
# 19358                600.44240  2022-04-08
# 19359               2225.97630  2022-04-08
# 19360                900.15970  2022-04-08
# 19361               1325.04590  2022-04-08
# 19362                601.19040  2022-04-08
#
# [19363 rows x 11 columns]

# %% [markdown]
# ## Labeled data

# %%
import json

with open(f'./labeled/{COIN}_{TIME}_labels.json', 'r') as fIn:
    labels = json.load(fIn)

labeled_data = labels[0]['annotations'][0]['result']
labeled_data
# Out:
# [{'value': {'start': '2021-03-02 20:30:00',
#    'end': '2021-03-03 12:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Ad814EZUSN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-01 06:30:00',
#    'end': '2021-03-02 00:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'YZ-6N5dP41',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-04 09:00:00',
#    'end': '2021-03-04 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '33XT-1l0rU',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-05 16:00:00',
#    'end': '2021-03-09 03:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '7z1CUrYjLG',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-13 01:00:00',
#    'end': '2021-03-13 20:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'amjkwVDdIb',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-11 09:30:00',
#    'end': '2021-03-11 21:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'R5bnHEdbjo',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-10 03:30:00',
#    'end': '2021-03-10 17:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'OnL6YJSkqv',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-19 00:00:00',
#    'end': '2021-03-20 13:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'JThm_aYbnl',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-17 11:00:00',
#    'end': '2021-03-18 02:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '1O8SCpfclr',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-16 00:30:00',
#    'end': '2021-03-16 08:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'stxldnp9Te',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-24 06:00:00',
#    'end': '2021-03-24 12:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '_NyjyLg7uN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-25 12:00:00',
#    'end': '2021-03-27 21:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'drDiS4XDyH',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-28 20:30:00',
#    'end': '2021-03-31 00:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'KJv07rtpHx',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-04 00:30:00',
#    'end': '2021-04-04 14:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'yX2eWsewHc',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-05 05:30:00',
#    'end': '2021-04-06 00:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'X5PpLwnD47',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-07 23:30:00',
#    'end': '2021-04-10 04:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'mDxiqGW0kE',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-12 17:30:00',
#    'end': '2021-04-15 22:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '6wTJfUcocH',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-16 10:30:00',
#    'end': '2021-04-17 02:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'wsZWlxsvFT',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-18 11:30:00',
#    'end': '2021-04-19 04:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'y4WkDMzxDy',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-20 07:00:00',
#    'end': '2021-04-22 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'rNVj4F0CDu',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-25 03:30:00',
#    'end': '2021-05-03 23:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'PeOd3RaQgr',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-07 04:00:00',
#    'end': '2021-05-10 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'w2Tdc5wdTM',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-11 03:00:00',
#    'end': '2021-05-12 05:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'IzGmzIFWGD',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-05 06:30:00',
#    'end': '2021-05-06 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'MtWBaanjze',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-13 18:30:00',
#    'end': '2021-05-14 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Y-lHbRuE3a',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-17 22:30:00',
#    'end': '2021-05-18 05:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'SFl0Kwm34e',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-17 03:00:00',
#    'end': '2021-05-17 08:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '7MA-otllC4',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-20 00:30:00',
#    'end': '2021-05-20 13:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '6fvHKLwh2z',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-23 16:00:00',
#    'end': '2021-05-25 00:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'm_UCCe21vZ',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-25 11:30:00',
#    'end': '2021-05-26 07:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'mHLIcffzyV',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-27 03:30:00',
#    'end': '2021-05-27 14:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'vCFGeKvPWV',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-28 21:00:00',
#    'end': '2021-05-29 05:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'epO1QT0UX5',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-30 01:00:00',
#    'end': '2021-05-30 07:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '4TT-2tWqyQ',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-31 03:00:00',
#    'end': '2021-06-01 00:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'YbbN7BG_B1',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-05-22 05:30:00',
#    'end': '2021-05-22 11:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'IetFnhcTFs',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-01 17:00:00',
#    'end': '2021-06-02 15:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ZTh6D0cdCm',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-03 01:30:00',
#    'end': '2021-06-03 10:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'l16NeqOcgp',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-04 12:30:00',
#    'end': '2021-06-05 08:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'DSpjiqvlz0',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-23 06:30:00',
#    'end': '2021-03-23 18:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '1BPVTgE67M',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-03-31 09:30:00',
#    'end': '2021-04-02 23:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '8YC_lCVD_R',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-04-23 07:30:00',
#    'end': '2021-04-23 19:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'oSrUAHGH67',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-05 21:00:00',
#    'end': '2021-06-07 10:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'E8F0FeG8hU',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-08 15:00:00',
#    'end': '2021-06-08 22:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'VvB-rX5QTa',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-09 04:00:00',
#    'end': '2021-06-09 22:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'fstjMnV253',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-12 02:00:00',
#    'end': '2021-06-12 13:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'uWlK_AGqBB',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-13 14:30:00',
#    'end': '2021-06-15 04:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'lTghoEdg0J',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-20 12:00:00',
#    'end': '2021-06-20 21:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'LyN4QY7zfN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-22 13:30:00',
#    'end': '2021-06-23 05:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'RFz0pr9T81',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-27 19:30:00',
#    'end': '2021-06-29 17:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'jZH2jy3Z3E',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-26 21:30:00',
#    'end': '2021-06-27 04:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'pJTTb70iO8',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-24 02:30:00',
#    'end': '2021-06-24 17:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'MnEBxf0nU5',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-02 12:00:00',
#    'end': '2021-07-04 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ydQSXkOteu',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-06-30 15:30:00',
#    'end': '2021-06-30 23:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'YE4Oq-p5EH',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-05 23:30:00',
#    'end': '2021-07-06 08:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'XXZxm7DgF_',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-06 21:30:00',
#    'end': '2021-07-07 05:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'dIHUQW6zqD',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-11 07:00:00',
#    'end': '2021-07-12 03:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'cbf-nIFPki',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-14 05:30:00',
#    'end': '2021-07-14 14:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'KMXCXCe1kU',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-17 10:30:00',
#    'end': '2021-07-18 02:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '9Hwget6Ny2',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-19 02:30:00',
#    'end': '2021-07-19 05:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '4e8IbxanaF',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-21 00:30:00',
#    'end': '2021-07-23 01:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'MgLLgzVaSp',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-23 16:30:00',
#    'end': '2021-07-24 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ptsjByZKsa',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-25 14:00:00',
#    'end': '2021-07-26 06:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Gg_N41bMhS',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-27 01:30:00',
#    'end': '2021-07-27 12:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'jeOcF8Zww2',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-30 16:30:00',
#    'end': '2021-08-01 20:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Wt8thpB8Uv',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-07-29 11:30:00',
#    'end': '2021-07-30 03:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'sAMhGRO3zW',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-04 07:30:00',
#    'end': '2021-08-08 07:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'rxbqD9QCru',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-09 06:00:00',
#    'end': '2021-08-09 19:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'F-0-hdmqTS',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-12 22:00:00',
#    'end': '2021-08-13 23:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'xUH6MyvK5j',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-15 17:00:00',
#    'end': '2021-08-16 01:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'l61Wypf0Ue',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-10 16:00:00',
#    'end': '2021-08-11 15:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '9dYoHapDVZ',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-19 11:30:00',
#    'end': '2021-08-20 16:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Of4QyNi3oL',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-22 20:00:00',
#    'end': '2021-08-23 05:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'YgZw56DcO6',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-25 09:00:00',
#    'end': '2021-08-26 01:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'rLK7Oi_mM9',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-27 03:30:00',
#    'end': '2021-08-27 21:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'DPa4wxcLTj',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-08-31 00:00:00',
#    'end': '2021-09-02 00:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'VkOC4WMfuX',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-03 00:30:00',
#    'end': '2021-09-03 14:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '4F8eHjg7X2',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-13 14:00:00',
#    'end': '2021-09-16 04:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'SASZNKU3ly',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-12 01:30:00',
#    'end': '2021-09-12 09:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ob78eAKFhE',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-08 07:00:00',
#    'end': '2021-09-08 19:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'LDiqLxlwsg',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-17 22:30:00',
#    'end': '2021-09-18 10:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'eJDc01PlH7',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-21 00:00:00',
#    'end': '2021-09-21 08:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'hvnk5gFR2q',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-21 22:30:00',
#    'end': '2021-09-23 08:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ld1CkXtPjk',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-26 07:30:00',
#    'end': '2021-09-27 01:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'dp8vHyO1Yk',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-29 20:00:00',
#    'end': '2021-10-02 19:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'W1hsku1lc6',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-09-28 23:30:00',
#    'end': '2021-09-29 12:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '3onQIvbaqN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-06 09:00:00',
#    'end': '2021-10-06 15:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '5KDDzbuCjj',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-07 01:00:00',
#    'end': '2021-10-08 08:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '1w7IaLnljg',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-04 15:00:00',
#    'end': '2021-10-05 21:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'LwNffHTEdi',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-10 23:30:00',
#    'end': '2021-10-11 09:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ext1nZae_5',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-13 08:30:00',
#    'end': '2021-10-15 05:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'zCWUyWPYtN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-15 08:30:00',
#    'end': '2021-10-16 11:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'HzrPSMEnn-',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-16 22:00:00',
#    'end': '2021-10-17 08:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'y6BoF_cDNX',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-18 22:00:00',
#    'end': '2021-10-21 11:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'IgYyib_wb9',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-17 20:00:00',
#    'end': '2021-10-18 01:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'GekKiGVaaE',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-24 18:00:00',
#    'end': '2021-10-26 00:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'wwmYVgU9w6',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-22 17:30:00',
#    'end': '2021-10-23 23:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ek_56prokS',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-28 00:30:00',
#    'end': '2021-10-29 15:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'YkvOzqv0on',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-10-31 12:00:00',
#    'end': '2021-11-03 00:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '34Z16l8pBU',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-06 12:30:00',
#    'end': '2021-11-09 05:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'alEpNAIBk6',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-10 21:30:00',
#    'end': '2021-11-12 01:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '4fS1y0Olht',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-18 22:30:00',
#    'end': '2021-11-20 01:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'PlbUo-D2EM',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-17 14:30:00',
#    'end': '2021-11-18 02:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'QDPqnHdW2i',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-14 18:30:00',
#    'end': '2021-11-15 13:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'XRqoo8dMZL',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-22 21:00:00',
#    'end': '2021-11-23 21:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Mj1uJGdb0F',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-24 19:00:00',
#    'end': '2021-11-25 23:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ggu6r3vMqf',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-28 17:30:00',
#    'end': '2021-12-01 07:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'aER_cpxU8r',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-04 05:00:00',
#    'end': '2021-12-05 12:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ITjFEp6qBr',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-06 10:00:00',
#    'end': '2021-12-07 09:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'FkZ1n_AGKD',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-15 16:00:00',
#    'end': '2021-12-15 21:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '2JWrPS0MBN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-20 14:00:00',
#    'end': '2021-12-21 12:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'd2kLIIDynM',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-18 01:30:00',
#    'end': '2021-12-18 10:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'oTUR_RmLrz',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-23 07:30:00',
#    'end': '2021-12-23 19:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Y8bIgwKD9H',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-26 03:30:00',
#    'end': '2021-12-27 18:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'z1WVBmu1n1',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-29 23:30:00',
#    'end': '2021-12-31 09:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'JxzVCplNJN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-12-31 19:30:00',
#    'end': '2022-01-02 17:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Iqx0_5rwXR',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-03 20:00:00',
#    'end': '2022-01-04 14:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ayMoNvHj0-',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-10 14:00:00',
#    'end': '2022-01-12 21:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'xQ4SwHpKqv',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-24 13:30:00',
#    'end': '2022-01-24 20:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ljF3zn_H-s',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-26 06:30:00',
#    'end': '2022-01-26 14:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Rqx7GcW8FP',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-20 09:00:00',
#    'end': '2022-01-20 15:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'UBq4ZyZhB-',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-31 04:00:00',
#    'end': '2022-02-01 21:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '3Tl4oUxNLJ',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-28 13:30:00',
#    'end': '2022-01-29 14:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'xMayTeHJoi',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-03 20:30:00',
#    'end': '2022-02-05 15:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Iit0syvFhq',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-06 22:30:00',
#    'end': '2022-02-08 06:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'AY02ExclHp',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-09 02:30:00',
#    'end': '2022-02-09 20:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'yeG_u989tu',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-14 19:00:00',
#    'end': '2022-02-15 23:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'lJDjdQqfNE',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-22 05:30:00',
#    'end': '2022-02-23 13:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'IkD5U6mm7B',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-24 07:00:00',
#    'end': '2022-02-26 21:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'XlQVpuBGYa',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-20 21:00:00',
#    'end': '2022-02-21 05:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'hSOhB7PKPT',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-28 06:00:00',
#    'end': '2022-03-01 13:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'u1-0NUOMsB',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-07 19:30:00',
#    'end': '2022-03-09 09:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '9YNYIpexdZ',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-15 08:00:00',
#    'end': '2022-03-18 19:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '6OD0c1PplK',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-11 02:30:00',
#    'end': '2022-03-11 12:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'cIBpDx_dcu',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-23 04:00:00',
#    'end': '2022-03-25 12:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'D-dik02iGR',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-21 03:30:00',
#    'end': '2022-03-22 04:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'hA2elvZ-ST',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-27 12:30:00',
#    'end': '2022-03-28 19:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '_Q0PmpihVq',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-28 23:30:00',
#    'end': '2022-03-29 12:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'oc_jsSIXXq',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-04-01 02:30:00',
#    'end': '2022-04-02 00:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'M87iI3g3xB',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-04-07 00:30:00',
#    'end': '2022-04-07 12:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'h_ntJgjXtN',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-04-07 15:00:00',
#    'end': '2022-04-08 09:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'iOSMMDQMK3',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-04-04 18:00:00',
#    'end': '2022-04-04 23:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Ffaqsx2f20',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-04-03 00:30:00',
#    'end': '2022-04-03 06:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'ImJ_tRoKV4',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-04-03 19:30:00',
#    'end': '2022-04-03 22:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'gG-r6vSqa8',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-30 15:00:00',
#    'end': '2022-03-30 17:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': '9rwENydl6n',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-30 01:30:00',
#    'end': '2022-03-30 06:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'Y4evUzYBTL',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-13 22:30:00',
#    'end': '2022-03-14 09:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'rDULxwEjDs',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-14 18:00:00',
#    'end': '2022-03-14 23:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'GPiH5MsogD',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-03-07 08:00:00',
#    'end': '2022-03-07 13:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'BAA8TvBZyw',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-02-27 01:30:00',
#    'end': '2022-02-27 11:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'IA12MLiEEA',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-27 03:30:00',
#    'end': '2022-01-27 14:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'LJyGaNshbB',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-23 02:30:00',
#    'end': '2022-01-23 09:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'mvHLKYyOIU',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-23 19:30:00',
#    'end': '2022-01-23 23:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'MRX1JYLQ19',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2022-01-06 12:00:00',
#    'end': '2022-01-06 19:00:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'MqM5OejuUe',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'},
#  {'value': {'start': '2021-11-20 15:30:00',
#    'end': '2021-11-20 21:30:00',
#    'instant': False,
#    'timeserieslabels': ['Regions']},
#   'id': 'I0F7oMFP6N',
#   'from_name': 'predictable',
#   'to_name': 'stock',
#   'type': 'timeserieslabels',
#   'origin': 'manual'}]

# %%
dict_labels = {}
count = 0
for value in labeled_data:
    if value['value']['end'] == '0NaN-NaN-NaN NaN:NaN:NaN':
        pass
    else:
        count +=1
        dict_labels[count] = [value['value']['start'], 1]
        count +=1
        dict_labels[count] = [value['value']['end'], 2]

labels = pd.DataFrame.from_dict(dict_labels, orient='index', columns=['timestamp', 'label'])
labels['timestamp'] = pd.to_datetime(labels.timestamp)

labels
# Out:
#               timestamp  label
# 1   2021-03-02 20:30:00      1
# 2   2021-03-03 12:30:00      2
# 3   2021-03-01 06:30:00      1
# 4   2021-03-02 00:00:00      2
# 5   2021-03-04 09:00:00      1
# ..                  ...    ...
# 304 2022-01-23 23:30:00      2
# 305 2022-01-06 12:00:00      1
# 306 2022-01-06 19:00:00      2
# 307 2021-11-20 15:30:00      1
# 308 2021-11-20 21:30:00      2
#
# [308 rows x 2 columns]

# %%
klines_label = klines.merge(labels, on='timestamp', how='outer')
klines_label = klines_label.fillna(0)

for i, row in klines_label.iterrows():
    if i > 1:
        last_row = klines_label.label.iloc[i-1]
        if last_row == 0 and row.label == 1:
            klines_label.loc[i, 'label'] = 1
        elif last_row == 1 and row.label == 0:
            klines_label.loc[i, 'label'] = 1
        elif last_row == 1 and row.label == 2:
            klines_label.loc[i, 'label'] = 2
        elif last_row == 2 and row.label == 0:
            klines_label.loc[i, 'label'] = 0
        else:
            klines_label.loc[i, 'label'] = 0
    else:
        pass

klines_label = klines_label.replace(2, 1)
klines_label['label'] = klines_label.label.shift(1)
klines_label = klines_label.fillna(0)
# klines['time'] = pd.to_datetime(klines['timestamp'].dt.strftime('%Y-%m-%d'))
klines_label
# Out:
#                 timestamp     open     high      low    close      volume  \
# 0     2021-03-01 00:00:00  1421.35  1450.88  1412.30  1441.50  9975.10635
# 1     2021-03-01 00:30:00  1441.73  1452.56  1441.19  1443.22  6350.20225
# 2     2021-03-01 01:00:00  1443.39  1449.55  1428.57  1435.20  6571.05176
# 3     2021-03-01 01:30:00  1435.04  1445.44  1434.62  1442.00  6196.16782
# 4     2021-03-01 02:00:00  1442.00  1458.62  1439.03  1452.11  8289.00965
# ...                   ...      ...      ...      ...      ...         ...
# 19358 2022-04-08 21:30:00  3237.45  3237.57  3214.37  3222.17  1487.87310
# 19359 2022-04-08 22:00:00  3222.65  3228.94  3192.33  3192.33  4534.63730
# 19360 2022-04-08 22:30:00  3192.31  3209.75  3186.55  3191.10  1826.88800
# 19361 2022-04-08 23:00:00  3191.10  3198.91  3175.88  3178.50  2805.18970
# 19362 2022-04-08 23:30:00  3178.51  3195.93  3171.94  3192.58  1392.22050
#
#            closetime  quoteassetvolume  numberoftrades  \
# 0      1614558599999      1.430813e+07           16898
# 1      1614560399999      9.185153e+06           12528
# 2      1614562199999      9.442462e+06           10972
# 3      1614563999999      8.922005e+06            9369
# 4      1614565799999      1.199415e+07           13042
# ...              ...               ...             ...
# 19358  1649455199999      4.795426e+06            5793
# 19359  1649456999999      1.453230e+07           11366
# 19360  1649458799999      5.844115e+06            5710
# 19361  1649460599999      8.936618e+06            9418
# 19362  1649462399999      4.432669e+06            5074
#
#        takerbuybaseassetvolume        time  label
# 0                   5022.33978  2021-03-01    0.0
# 1                   3154.76630  2021-03-01    0.0
# 2                   3084.98996  2021-03-01    0.0
# 3                   3188.12220  2021-03-01    0.0
# 4                   3857.25552  2021-03-01    0.0
# ...                        ...         ...    ...
# 19358                600.44240  2022-04-08    0.0
# 19359               2225.97630  2022-04-08    0.0
# 19360                900.15970  2022-04-08    0.0
# 19361               1325.04590  2022-04-08    0.0
# 19362                601.19040  2022-04-08    0.0
#
# [19363 rows x 12 columns]

# %% [markdown]
# ## Merge & Feature Eng.

# %%
import pandas_ta as pta
import numpy as np

# df = klines_label.merge(greed, left_on='time', right_on='time')
df = klines_label.copy()
df = df[['timestamp', 'open', 'high', 'low', 'close', 'volume', 'numberoftrades', 'label']]

df['candle_hight'] = 100 * (df.high - df.low) / ((df.high + df.low) / 2)
df['price_change'] = df['close'].pct_change() * 100
df['FASTMA'] = df.close.rolling(200).mean() # 30 $26 %32
df['SLOWMA'] = df.close.ewm(150).mean() # 100 $26 %32
df['FASTSlope'] = np.degrees(np.arctan(df['FASTMA'].diff()/200))
df['SLOWSlope'] = np.degrees(np.arctan(df['SLOWMA'].diff()/150))
df['RSI'] = pta.rsi(df.close)
df['Slope'] = pta.slope(df.close, length=7)
df['AROON'] = pta.aroon(df['high'], df['low'])['AROONU_14']
df['BBAND'] = pta.bbands(df['close'], length=14, std=2, talib=False)['BBP_14_2.0']
df['OBV'] = pta.bbands(close=df['close'], volume=df['volume'])['BBP_5_2.0']
df['MACD'] = pta.macd(close=df['close'])['MACD_12_26_9']

df = df.dropna()
df = df.sort_values('timestamp')
df
# Out:
#                 timestamp     open     high      low    close      volume  \
# 200   2021-03-05 04:00:00  1481.80  1481.89  1469.86  1477.70  4432.30353
# 201   2021-03-05 04:30:00  1477.67  1487.00  1465.10  1465.78  5795.59382
# 202   2021-03-05 05:00:00  1465.78  1479.01  1461.62  1468.57  6958.73688
# 203   2021-03-05 05:30:00  1468.25  1475.30  1465.33  1472.43  6413.12447
# 204   2021-03-05 06:00:00  1472.43  1484.37  1469.15  1474.37  4703.41044
# ...                   ...      ...      ...      ...      ...         ...
# 19358 2022-04-08 21:30:00  3237.45  3237.57  3214.37  3222.17  1487.87310
# 19359 2022-04-08 22:00:00  3222.65  3228.94  3192.33  3192.33  4534.63730
# 19360 2022-04-08 22:30:00  3192.31  3209.75  3186.55  3191.10  1826.88800
# 19361 2022-04-08 23:00:00  3191.10  3198.91  3175.88  3178.50  2805.18970
# 19362 2022-04-08 23:30:00  3178.51  3195.93  3171.94  3192.58  1392.22050
#
#        numberoftrades  label  candle_hight  price_change      FASTMA  \
# 200              7658    0.0      0.815110     -0.280055  1541.78060
# 201              9663    0.0      1.483690     -0.806659  1541.89340
# 202             10613    0.0      1.182740      0.190342  1542.06025
# 203              9454    0.0      0.678086      0.262841  1542.21240
# 204              8226    0.0      1.030635      0.131755  1542.32370
# ...               ...    ...           ...           ...         ...
# 19358            5793    0.0      0.719164     -0.471976  3325.29015
# 19359           11366    0.0      1.140273     -0.926084  3324.08475
# 19360            5710    0.0      0.725419     -0.038530  3322.72985
# 19361            9418    0.0      0.722534     -0.394848  3321.22885
# 19362            5074    0.0      0.753470      0.442976  3319.72940
#
#             SLOWMA  FASTSlope  SLOWSlope        RSI     Slope      AROON  \
# 200    1546.472415   0.051853  -0.238192  36.445367 -0.151429  35.714286
# 201    1545.749028   0.032315  -0.276311  33.321409 -0.127143  28.571429
# 202    1545.058755   0.047799  -0.263663  34.731601  0.867143  21.428571
# 203    1544.410683   0.043588  -0.247544  36.725436  0.428571  14.285714
# 204    1543.787138   0.031885  -0.238175  37.754618 -0.911429   7.142857
# ...            ...        ...        ...        ...       ...        ...
# 19358  3323.939723  -0.310454  -0.259153  41.258749 -2.075714   7.142857
# 19359  3323.068135  -0.345317  -0.332918  35.267867 -9.588571   0.000000
# 19360  3322.194174  -0.388144  -0.333825  35.041999 -9.991429   0.000000
# 19361  3321.242557  -0.429997  -0.363486  32.729583 -8.705714   0.000000
# 19362  3320.390487  -0.429553  -0.325463  37.678728 -6.188571   0.000000
#
#           BBAND       OBV       MACD
# 200    0.335641  0.502630 -21.224786
# 201    0.259240  0.016928 -21.563686
# 202    0.315449  0.261114 -21.360902
# 203    0.380329  0.464380 -20.650676
# 204    0.434130  0.654516 -19.704139
# ...         ...       ...        ...
# 19358  0.109637  0.090486  -6.783982
# 19359 -0.083658  0.055100 -10.559449
# 19360  0.011841  0.210361 -13.495220
# 19361 -0.010971  0.205572 -16.646662
# 19362  0.172823  0.452183 -17.802844
#
# [19163 rows x 20 columns]

# %% [markdown]
# ## Model

# %%
df.columns
# Out:
# Index(['timestamp', 'open', 'high', 'low', 'close', 'volume', 'numberoftrades',
#        'label', 'candle_hight', 'price_change', 'FASTMA', 'SLOWMA',
#        'FASTSlope', 'SLOWSlope', 'RSI', 'Slope', 'AROON', 'BBAND', 'OBV',
#        'MACD'],
#       dtype='object')

# %%
ml = df.copy()

to_remove = ['timestamp', 'numberoftrades', 'FASTMA', 'SLOWMA', 'SLOWSlope', 'FASTSlope', 'open', 'high', 'low', 'close','label']

columns = df.columns
columns = [i for i in columns if i not in to_remove]
columns.append('label')

ml = ml[columns] # label at the end
ml = ml.astype('float32')
ml.describe().T
# Out:
#                 count         mean          std         min          25%  \
# volume        19163.0  4470.489258  4098.453613  109.856483  1964.235291
# candle_hight  19163.0     1.011195     0.874594    0.126805     0.557572
# price_change  19163.0     0.006770     0.742622  -10.533595    -0.326680
# RSI           19163.0    51.085865    12.034963    9.295355    42.961700
# Slope         19163.0     0.090550     8.106643  -85.715714    -3.562143
# AROON         19163.0    48.255192    36.194290    0.000000    14.285714
# BBAND         19163.0     0.512895     0.321972   -0.355125     0.261548
# OBV           19163.0     0.507824     0.284999    0.000296     0.252428
# MACD          19163.0     0.627945    23.997801 -191.294342   -11.027146
# label         19163.0     0.414288     0.492612    0.000000     0.000000
#
#                       50%          75%           max
# volume        3279.780273  5580.610840  65719.000000
# candle_hight     0.800204     1.192798     45.478561
# price_change     0.013629     0.348055      6.186742
# RSI             51.330589    58.998127     87.416809
# Slope            0.277143     3.921429     69.428574
# AROON           50.000000    85.714287    100.000000
# BBAND            0.529837     0.764309      1.373518
# OBV              0.519846     0.758787      0.999049
# MACD             2.048237    13.905313     97.664062
# label            0.000000     1.000000      1.000000

# %%
import seaborn as sns

corr = ml.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, annot=True,  vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
# pd.plotting.scatter_matrix(ml, figsize=(10,10), color='black', alpha=0.75, diagonal='kde', grid=True)

# %%
# Function from https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
total_columns = len(ml.columns)

reframed = series_to_supervised(ml, 28, 1)
variable_name = f'var10'

# remove the label column from each time step
columns = []
for columnName, columnData in reframed.iteritems():
    if variable_name in columnName:
        if columnName == variable_name+'(t)':
            pass
        else:
            columns.append(columnName)

reframed = reframed.drop(columns, axis=1)

# remove the last time step but not the label
columns_to_remove = reframed.iloc[:, -total_columns:-1].columns
reframed = reframed.drop(columns_to_remove, axis=1)
reframed
# Out:
#         var1(t-28)  var2(t-28)  var3(t-28)  var4(t-28)  var5(t-28)  \
# 228    4432.303711    0.815110   -0.280055   36.445366   -0.151429
# 229    5795.593750    1.483690   -0.806659   33.321407   -0.127143
# 230    6958.736816    1.182740    0.190342   34.731602    0.867143
# 231    6413.124512    0.678086    0.262841   36.725437    0.428571
# 232    4703.410645    1.030635    0.131755   37.754620   -0.911429
# ...            ...         ...         ...         ...         ...
# 19358  4383.622559    1.332511    1.117535   63.298309    4.107143
# 19359  4967.621582    0.546475    0.216046   65.068878    4.940000
# 19360  3659.298584    0.839873   -0.013056   64.864784    3.780000
# 19361  2276.058594    0.475130    0.211661   66.688667    4.221428
# 19362  2454.584229    0.690483   -0.318488   61.504089    3.515714
#
#        var6(t-28)  var7(t-28)  var8(t-28)  var9(t-28)   var1(t-27)  ...  \
# 228     35.714287    0.335641    0.502630  -21.224787  5795.593750  ...
# 229     28.571428    0.259240    0.016928  -21.563686  6958.736816  ...
# 230     21.428572    0.315449    0.261114  -21.360903  6413.124512  ...
# 231     14.285714    0.380329    0.464380  -20.650677  4703.410645  ...
# 232      7.142857    0.434130    0.654516  -19.704138  3981.499512  ...
# ...           ...         ...         ...         ...          ...  ...
# 19358  100.000000    1.042062    0.900271   11.817545  4967.621582  ...
# 19359  100.000000    1.090141    0.837361   13.488503  3659.298584  ...
# 19360  100.000000    0.975280    0.721950   14.609642  2276.058594  ...
# 19361   92.857140    0.982269    0.716600   15.877546  2454.584229  ...
# 19362   85.714287    0.762789    0.336920   15.851574  1921.416748  ...
#
#           var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var6(t-1)  \
# 228     7899.086426   1.113954   0.618771  56.509995  -0.277143   57.142857
# 229    12026.096680   1.583113   1.184822  60.842052   4.474286  100.000000
# 230     7012.333984   0.790399  -0.226191  59.606892   3.562857   92.857140
# 231     6534.503906   1.278949   0.960041  63.029743   7.798572  100.000000
# 232     6236.620117   0.792599  -0.154255  62.110294  11.932858  100.000000
# ...             ...        ...        ...        ...        ...         ...
# 19358    862.226685   0.622930  -0.411894  44.884045  -1.221429   14.285714
# 19359   1487.873047   0.719164  -0.471976  41.258747  -2.075714    7.142857
# 19360   4534.637207   1.140273  -0.926084  35.267868  -9.588572    0.000000
# 19361   1826.887939   0.725419  -0.038530  35.042000  -9.991428    0.000000
# 19362   2805.189697   0.722534  -0.394848  32.729584  -8.705714    0.000000
#
#        var7(t-1)  var8(t-1)  var9(t-1)  var10(t)
# 228     0.845967   0.810597   0.634463       1.0
# 229     0.994387   0.825255   3.662571       1.0
# 230     0.872743   0.728542   5.718068       1.0
# 231     0.958375   0.844315   8.428806       1.0
# 232     0.861484   0.719564  10.267490       1.0
# ...          ...        ...        ...       ...
# 19358   0.245453   0.305377  -4.904692       0.0
# 19359   0.109637   0.090486  -6.783982       0.0
# 19360  -0.083658   0.055100 -10.559449       0.0
# 19361   0.011841   0.210361 -13.495219       0.0
# 19362  -0.010971   0.205572 -16.646662       0.0
#
# [19135 rows x 253 columns]

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

X = reframed.drop([variable_name+'(t)'], axis=1)
y = reframed[variable_name+'(t)']

X1 = df.drop(['label'], axis=1)
y1 = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=False)
_, X_backtest, _, y_backtest = train_test_split(X1, y1, test_size=0.3, random_state=42, shuffle=False)

print(X_train.shape)
print(y_train.shape)
print(y_train.value_counts())
# Out:
# (13394, 252)
# (13394,)
# 0.0    7431
# 1.0    5963
# Name: var10(t), dtype: int64

# %% [markdown]
# ### Random Forest

# %%
import pickle
model = pickle.load(open(f'./models/{COIN}.sav', 'rb'))

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# #### Predict and confusion matrix

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[3193,  627],
#        [ 940, 1033]], dtype=int64)

# %% [markdown]
# #### Precision, Recall and F1 Score

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate Precision Score, Recall Score and F1 Score
precision_score_p = precision_score(y_test, y_pred)
print('Precision Score: ', precision_score_p)

recall_score_p = recall_score(y_test, y_pred)
print('Recall Score: ', recall_score_p)

f1_score_p = f1_score(y_test, y_pred)
print('F1 Score: ', f1_score_p)
# Out:
# Precision Score:  0.6222891566265061
# Recall Score:  0.523568170299037
# F1 Score:  0.5686760253234243

# %% [markdown]
# #### Precision Recall Curve

# %%
from sklearn.metrics import precision_recall_curve

precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred)

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], 'b--', label='Precision')
    plt.plot(thresholds, recalls[:-1], 'r-', label='Recall')
    plt.xlabel('threshold')
    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.ylabel('%')

plot_precision_recall_vs_threshold(precisions, recalls, thresholds)

plt.show()

# %% [markdown]
# #### Roc Curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# plot the Roc Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0,1], [0,1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate(Recall)')

plot_roc_curve(fpr, tpr)
plt.show()

print('ROC Score: ', roc_auc_score(y_test, y_pred))
# Out:
# ROC Score:  0.6797160223222934

# %% [markdown]
# ## BackTest & Visualise

# %%
t_start = 0
t_end = 4700
threshold = .45
start = start = len(X_backtest) - len(X_test) - 1

yhat = model.predict_proba(X_test)
yhat = [i[1] for i in yhat]

price = X_backtest.iloc[start:,4].to_list()
slowma = X_backtest.iloc[start:,9].to_list()
slowma100 = X_backtest.iloc[start:,10].to_list()
slope = X_backtest.iloc[start:,11].to_list()
slope100 = X_backtest.iloc[start:,12].to_list()

new_order = False
amount = 100
leverage = 1
quantity=0
total=0
bought_price=0
total_earned = []
bought_at = []
amount_plot = []
win_percentage = []
prediction_data = []
price_data = []

for i in range(t_start, t_end):
    try:
        prediction = yhat[i]
        coin_price = price[i]
        price_data.append(coin_price)
        amount_plot.append(amount)
        prediction_data.append(prediction)

        if (new_order is False) and ((prediction > threshold) and (slope100[i] > 0)):
            quantity = round(amount / coin_price, 5)
            bought_price = coin_price
            total_earned.append(0)
            bought_at.append(1)
            new_order = True

        elif (new_order is True) and ((prediction < threshold) and ((slope100[i] < 0)) or (coin_price < bought_price * .99)):
            total_earn = (quantity * coin_price - amount) * leverage
            win_percentage.append(1 - bought_price / coin_price)
            # amount = amount + total_earn
            total += total_earn
            total_earned.append(total_earn)
            bought_at.append(0)

            new_order = False

        else:
            bought_at.append(0)
            total_earned.append(0)
            pass

    except:
        pass

total
# Out:
# -5.170177799999962

# %%
fig, ax1 = plt.subplots(figsize=(15,5), dpi=100)
color = 'tab:red'
ax1.plot(price_data, color=color)
# ax1.axes.yaxis.set_visible(False)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.plot(prediction_data, color=color, alpha=0.1)
ax2.axhline(y=.45, color=color, linestyle='-')
ax2.axes.yaxis.set_visible(False)

ax3 = ax1.twinx()
color = 'tab:green'
ax3.plot(total_earned, color=color, alpha=0.4)
# ax3.axes.yaxis.set_visible(False)

ax3 = ax1.twinx()
color = 'tab:green'
ax3.plot(slowma[t_start:t_end], color=color, alpha=0.4)
ax3.axes.yaxis.set_visible(False)
#
ax3 = ax1.twinx()
color = 'tab:pink'
ax3.plot(bought_at, color=color, alpha=0.4)
ax3.axes.yaxis.set_visible(False)

# %%
positive = 0
negative = 0

total_earn = 0
total_loss = 0

for i in total_earned:
    if i == 0:
        pass
    elif i > 0:

        positive = positive + 1
        total_earn = total_earn + i
    else:
        negative = negative + 1
        total_loss = total_loss + i

perc = positive/(positive+negative)

print('Total Trades: ', positive+negative)
print('Total Positive: ', positive, total_earn)
print('Total Negative: ', negative, total_loss)
print('Winning Rate: ', perc)
print('Average Profit: ', np.mean(win_percentage))
# Out:
# Total Trades:  10
# Total Positive:  2 16.839562200000003
# Total Negative:  8 -8.560073299999942
# Winning Rate:  0.2
# Average Profit:  0.006391558325100233

# %%
pd.Series(win_percentage).sort_values(ascending=False) * 100
# Out:
# 5    20.749411
# 6     2.606376
# 2    -0.011643
# 1    -0.312253
# 0    -1.162451
# 3    -1.299217
# 4    -1.838673
# dtype: float64

# %% [markdown]
# #### Feature Importance

# %%
from matplotlib.pyplot import figure
columns = list(X_train.columns)
features_importance = model.feature_importances_
figure(figsize=(8, 20), dpi=100)
plt.barh(columns, features_importance)
plt.plot()
# Out:
# []

# %% [markdown]
# ## Save Model!

# %%
import pickle
filename = f'./models/{COIN}.sav'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ## Test with Real data

# %%
from sqlalchemy import create_engine
import json

def db_connection():
    f = open("keys.json")
    data = json.load(f)
    engine = create_engine(data['connection'])

    return engine

with open('keys.json', 'r') as fIn:
    keys = json.load(fIn)

# %%
import pandas as pd
# AND timestamp BETWEEN '2022-03-30 09:00:00' AND '2022-03-30 23:00:00'
data = pd.read_sql_query("SELECT timestamp, price, prediction FROM data WHERE COIN = 'ETHBUSD' AND timestamp BETWEEN '2022-04-06 00:00:00' AND '2022-04-06 09:00:00'", db_connection(), index_col='timestamp')
data
# Out:
#                        price  prediction
# timestamp
# 2022-04-06 00:00:31  3446.33    0.223333
# 2022-04-06 00:01:03  3446.14    0.230000
# 2022-04-06 00:01:36  3443.64    0.223333
# 2022-04-06 00:02:08  3440.78    0.223333
# 2022-04-06 00:02:40  3439.81    0.220000
# ...                      ...         ...
# 2022-04-06 08:57:51  3350.70    0.230000
# 2022-04-06 08:58:23  3348.48    0.233333
# 2022-04-06 08:58:55  3345.95    0.226667
# 2022-04-06 08:59:27  3345.29    0.226667
# 2022-04-06 08:59:59  3346.78    0.226667
#
# [2056 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(15,5), dpi=100)
color = 'tab:red'
ax1.plot(data.price, color=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.plot(data.prediction, color=color)
# ax2.set_ylim(0,1)
ax2.axhline(y=.4, color=color, linestyle='-')

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(15,5), dpi=100)
color = 'tab:red'
ax1.plot(data.price, color=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.plot(data.prediction, color=color)
# ax2.set_ylim(0,1)
ax2.axhline(y=.38, color=color, linestyle='-')
